# %%
# Imports
import tensorflow
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, LeakyReLU, Dropout, BatchNormalization
from tensorflow.keras.optimizers import SGD, Adam

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys, os

# %%
# Load data
mnist = tensorflow.keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Map inputs to [-1/+1]
x_train, x_test = x_train / 255.0 * 2 - 1, x_test / 255.0 * 2 - 1
print("Training shape: ", x_train.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# Training shape:  (60000, 28, 28)

# %%
# Flatten data into 1d array
N, H, W = x_train.shape
D = H * W
x_train = x_train.reshape(-1, D)
x_test = x_test.reshape(-1, D)

# %%
# Select latent space size
latent_dim = 100

# %%
def build_gen (latent_dim):
    i = Input(shape=(latent_dim))
    x = Dense(256, activation=LeakyReLU(alpha=0.2))(i)
    x = BatchNormalization(momentum=0.8)(x)
    x = Dense(512, activation=LeakyReLU(alpha=0.2))(x)
    x = BatchNormalization(momentum=0.8)(x)
    x = Dense(1024, activation=LeakyReLU(alpha=0.2))(x)
    x = BatchNormalization(momentum=0.8)(x)
    x = Dense(D, activation="tanh")(x)

    model = Model(i, x)
    return model

# %%
def build_discr(img_size):
    i = Input(shape=(img_size,))
    x = Dense(512, activation=LeakyReLU(alpha=0.2))(i)
    x = Dense(256, activation=LeakyReLU(alpha=0.2))(x)
    x = Dense(1, activation="sigmoid")(x)

    model = Model(i, x)
    return model

# %%
# Compile both models
discriminator = build_discr(D)
discriminator.compile(
    loss="binary_crossentropy",
    optimizer=Adam(0.0002, 0.5),
    metrics=["accuracy"]
)

generator = build_gen(latent_dim)

z = Input(shape=(latent_dim,))
img = generator(z)
discriminator.trainable = False

fake_pred = discriminator(img)

gan = Model(z, fake_pred)
gan.compile(
    loss="binary_crossentropy",
    optimizer=Adam(0.0002, 0.5)
)

# %%
# Config for training
batch_size = 32
epochs = 30000
sample_period = 200

ones = np.ones(batch_size)
zeros = np.zeros(batch_size)

d_losses = []
g_losses = []

if not os.path.exists("images"):
    os.mkdir("images")

# %%
def sample_images(epoch):
    rows, cols = 5, 5
    noise = np.random.randn(rows * cols, latent_dim)
    imgs = generator.predict(noise)

    imgs = 0.5 * imgs + 0.5

    fig, axs = plt.subplots(rows, cols)
    idx = 0
    for i in range(rows):
        for j in range(cols):
            axs[i, j].imshow(imgs[idx].reshape(H, W), cmap="gray")
            axs[i, j].axis("off")
            idx += 1
    fig.savefig("images/%d.png" % epoch)
    plt.close()

# %%
# Main train loop
for epoch in range(epochs):
    # Select a random batch of images
    idx = np.random.randint(0, x_train.shape[0], batch_size)
    real_imgs = x_train[idx]

    # Generate fake images
    noise = np.random.randn(batch_size, latent_dim)
    fake_imgs = generator.predict(noise)

    # Train discriminator
    r = discriminator.fit(real_imgs, ones, verbose=0)
    d_loss_real, d_acc_real = r.history["loss"][0], r.history["accuracy"][0]
    r = discriminator.fit(fake_imgs, zeros, verbose=0)
    d_loss_fake, d_acc_fake = r.history["loss"][0], r.history["accuracy"][0]
    d_loss = 0.5 * (d_loss_real + d_loss_fake)
    d_acc = 0.5 * (d_acc_real + d_acc_fake)

    # Train generator
    noise = np.random.randn(batch_size, latent_dim)
    g_loss = gan.train_on_batch(noise, ones)


    # Save losses
    d_losses.append(d_loss)
    g_losses.append(g_loss)

    if (epoch % 100 == 0):
        print(f"Epoch: {epoch + 1}/{epochs}, D_loss: {d_loss:.2f}, D_acc: {d_acc:.2f}, G_loss: {g_loss:.2f}")
    
    if (epoch % sample_period == 0):
        sample_images(epoch)
# Out:
# Epoch: 1/30000, D_loss: 0.67, D_acc: 0.50, G_loss: 0.59
# Epoch: 101/30000, D_loss: 0.01, D_acc: 1.00, G_loss: 4.71
# Epoch: 201/30000, D_loss: 0.34, D_acc: 0.88, G_loss: 4.39
# Epoch: 301/30000, D_loss: 0.13, D_acc: 0.98, G_loss: 3.12
# Epoch: 401/30000, D_loss: 0.70, D_acc: 0.59, G_loss: 1.72
# Epoch: 501/30000, D_loss: 0.68, D_acc: 0.44, G_loss: 0.75
# Epoch: 601/30000, D_loss: 0.65, D_acc: 0.61, G_loss: 0.72
# Epoch: 701/30000, D_loss: 0.62, D_acc: 0.70, G_loss: 0.79
# Epoch: 801/30000, D_loss: 0.60, D_acc: 0.66, G_loss: 0.81
# Epoch: 901/30000, D_loss: 0.65, D_acc: 0.64, G_loss: 0.83
# Epoch: 1001/30000, D_loss: 0.63, D_acc: 0.67, G_loss: 0.82
# Epoch: 1101/30000, D_loss: 0.59, D_acc: 0.72, G_loss: 0.84
# Epoch: 1201/30000, D_loss: 0.66, D_acc: 0.58, G_loss: 0.83
# Epoch: 1301/30000, D_loss: 0.55, D_acc: 0.77, G_loss: 0.92
# Epoch: 1401/30000, D_loss: 0.57, D_acc: 0.75, G_loss: 0.97
# Epoch: 1501/30000, D_loss: 0.52, D_acc: 0.81, G_loss: 0.97
# Epoch: 1601/30000, D_loss: 0.59, D_acc: 0.69, G_loss: 1.00
# Epoch: 1701/30000, D_loss: 0.57, D_acc: 0.69, G_loss: 1.05
# Epoch: 1801/30000, D_loss: 0.58, D_acc: 0.72, G_loss: 0.96
# Epoch: 1901/30000, D_loss: 0.52, D_acc: 0.81, G_loss: 1.00
# Epoch: 2001/30000, D_loss: 0.65, D_acc: 0.56, G_loss: 1.03
# Epoch: 2101/30000, D_loss: 0.59, D_acc: 0.72, G_loss: 1.02
# Epoch: 2201/30000, D_loss: 0.58, D_acc: 0.70, G_loss: 0.90
# Epoch: 2301/30000, D_loss: 0.59, D_acc: 0.67, G_loss: 1.02
# Epoch: 2401/30000, D_loss: 0.56, D_acc: 0.72, G_loss: 1.07
# Epoch: 2501/30000, D_loss: 0.58, D_acc: 0.77, G_loss: 0.96
# Epoch: 2601/30000, D_loss: 0.57, D_acc: 0.69, G_loss: 1.04
# Epoch: 2701/30000, D_loss: 0.59, D_acc: 0.77, G_loss: 1.13
# Epoch: 2801/30000, D_loss: 0.70, D_acc: 0.52, G_loss: 1.03
# Epoch: 2901/30000, D_loss: 0.64, D_acc: 0.61, G_loss: 0.96
# Epoch: 3001/30000, D_loss: 0.53, D_acc: 0.77, G_loss: 1.02
# Epoch: 3101/30000, D_loss: 0.59, D_acc: 0.69, G_loss: 0.99
# Epoch: 3201/30000, D_loss: 0.57, D_acc: 0.72, G_loss: 1.00
# Epoch: 3301/30000, D_loss: 0.64, D_acc: 0.59, G_loss: 0.97
# Epoch: 3401/30000, D_loss: 0.67, D_acc: 0.61, G_loss: 1.01
# Epoch: 3501/30000, D_loss: 0.55, D_acc: 0.72, G_loss: 1.07
# Epoch: 3601/30000, D_loss: 0.54, D_acc: 0.72, G_loss: 0.92
# Epoch: 3701/30000, D_loss: 0.60, D_acc: 0.67, G_loss: 0.99
# Epoch: 3801/30000, D_loss: 0.58, D_acc: 0.69, G_loss: 1.02
# Epoch: 3901/30000, D_loss: 0.51, D_acc: 0.77, G_loss: 0.99
# Epoch: 4001/30000, D_loss: 0.61, D_acc: 0.70, G_loss: 0.97
# Epoch: 4101/30000, D_loss: 0.53, D_acc: 0.73, G_loss: 1.04
# Epoch: 4201/30000, D_loss: 0.58, D_acc: 0.72, G_loss: 1.03
# Epoch: 4301/30000, D_loss: 0.58, D_acc: 0.69, G_loss: 1.08
# Epoch: 4401/30000, D_loss: 0.59, D_acc: 0.72, G_loss: 1.03
# Epoch: 4501/30000, D_loss: 0.60, D_acc: 0.62, G_loss: 1.03
# Epoch: 4601/30000, D_loss: 0.63, D_acc: 0.66, G_loss: 0.98
# Epoch: 4701/30000, D_loss: 0.57, D_acc: 0.77, G_loss: 0.92
# Epoch: 4801/30000, D_loss: 0.69, D_acc: 0.58, G_loss: 1.03
# Epoch: 4901/30000, D_loss: 0.62, D_acc: 0.67, G_loss: 0.91
# Epoch: 5001/30000, D_loss: 0.64, D_acc: 0.67, G_loss: 0.98
# Epoch: 5101/30000, D_loss: 0.59, D_acc: 0.69, G_loss: 0.95
# Epoch: 5201/30000, D_loss: 0.59, D_acc: 0.70, G_loss: 1.00
# Epoch: 5301/30000, D_loss: 0.64, D_acc: 0.62, G_loss: 1.05
# Epoch: 5401/30000, D_loss: 0.66, D_acc: 0.58, G_loss: 1.02
# Epoch: 5501/30000, D_loss: 0.63, D_acc: 0.66, G_loss: 0.95
# Epoch: 5601/30000, D_loss: 0.56, D_acc: 0.75, G_loss: 0.94
# Epoch: 5701/30000, D_loss: 0.49, D_acc: 0.80, G_loss: 1.06
# Epoch: 5801/30000, D_loss: 0.62, D_acc: 0.66, G_loss: 1.01
# Epoch: 5901/30000, D_loss: 0.58, D_acc: 0.69, G_loss: 1.00
# Epoch: 6001/30000, D_loss: 0.69, D_acc: 0.61, G_loss: 1.03
# Epoch: 6101/30000, D_loss: 0.56, D_acc: 0.73, G_loss: 1.12
# Epoch: 6201/30000, D_loss: 0.59, D_acc: 0.73, G_loss: 0.89
# Epoch: 6301/30000, D_loss: 0.63, D_acc: 0.67, G_loss: 0.96
# Epoch: 6401/30000, D_loss: 0.65, D_acc: 0.61, G_loss: 0.94
# Epoch: 6501/30000, D_loss: 0.57, D_acc: 0.72, G_loss: 0.95
# Epoch: 6601/30000, D_loss: 0.52, D_acc: 0.77, G_loss: 1.02
# Epoch: 6701/30000, D_loss: 0.62, D_acc: 0.67, G_loss: 1.04
# Epoch: 6801/30000, D_loss: 0.63, D_acc: 0.67, G_loss: 0.91
# Epoch: 6901/30000, D_loss: 0.64, D_acc: 0.64, G_loss: 0.91
# Epoch: 7001/30000, D_loss: 0.65, D_acc: 0.62, G_loss: 0.99
# Epoch: 7101/30000, D_loss: 0.60, D_acc: 0.61, G_loss: 1.00
# Epoch: 7201/30000, D_loss: 0.64, D_acc: 0.62, G_loss: 1.05
# Epoch: 7301/30000, D_loss: 0.61, D_acc: 0.75, G_loss: 0.93
# Epoch: 7401/30000, D_loss: 0.67, D_acc: 0.61, G_loss: 0.94
# Epoch: 7501/30000, D_loss: 0.67, D_acc: 0.69, G_loss: 0.97
# Epoch: 7601/30000, D_loss: 0.69, D_acc: 0.53, G_loss: 0.91
# Epoch: 7701/30000, D_loss: 0.65, D_acc: 0.62, G_loss: 0.95
# Epoch: 7801/30000, D_loss: 0.52, D_acc: 0.80, G_loss: 1.02
# Epoch: 7901/30000, D_loss: 0.56, D_acc: 0.73, G_loss: 0.96
# Epoch: 8001/30000, D_loss: 0.57, D_acc: 0.66, G_loss: 1.04
# Epoch: 8101/30000, D_loss: 0.61, D_acc: 0.70, G_loss: 0.91
# Epoch: 8201/30000, D_loss: 0.57, D_acc: 0.70, G_loss: 1.01
# Epoch: 8301/30000, D_loss: 0.63, D_acc: 0.61, G_loss: 1.02
# Epoch: 8401/30000, D_loss: 0.58, D_acc: 0.67, G_loss: 1.05
# Epoch: 8501/30000, D_loss: 0.67, D_acc: 0.66, G_loss: 1.04
# Epoch: 8601/30000, D_loss: 0.70, D_acc: 0.59, G_loss: 0.97
# Epoch: 8701/30000, D_loss: 0.62, D_acc: 0.62, G_loss: 0.85
# Epoch: 8801/30000, D_loss: 0.64, D_acc: 0.67, G_loss: 0.98
# Epoch: 8901/30000, D_loss: 0.65, D_acc: 0.56, G_loss: 1.00
# Epoch: 9001/30000, D_loss: 0.69, D_acc: 0.69, G_loss: 0.96
# Epoch: 9101/30000, D_loss: 0.62, D_acc: 0.58, G_loss: 1.11
# Epoch: 9201/30000, D_loss: 0.69, D_acc: 0.64, G_loss: 0.99
# Epoch: 9301/30000, D_loss: 0.64, D_acc: 0.62, G_loss: 1.00
# Epoch: 9401/30000, D_loss: 0.62, D_acc: 0.66, G_loss: 0.91
# Epoch: 9501/30000, D_loss: 0.67, D_acc: 0.64, G_loss: 1.00
# Epoch: 9601/30000, D_loss: 0.69, D_acc: 0.55, G_loss: 0.87
# Epoch: 9701/30000, D_loss: 0.65, D_acc: 0.56, G_loss: 0.94
# Epoch: 9801/30000, D_loss: 0.63, D_acc: 0.70, G_loss: 1.03
# Epoch: 9901/30000, D_loss: 0.69, D_acc: 0.56, G_loss: 0.95
# Epoch: 10001/30000, D_loss: 0.64, D_acc: 0.64, G_loss: 0.99
# Epoch: 10101/30000, D_loss: 0.63, D_acc: 0.67, G_loss: 1.00
# Epoch: 10201/30000, D_loss: 0.65, D_acc: 0.62, G_loss: 0.98
# Epoch: 10301/30000, D_loss: 0.66, D_acc: 0.56, G_loss: 0.95
# Epoch: 10401/30000, D_loss: 0.62, D_acc: 0.66, G_loss: 1.06
# Epoch: 10501/30000, D_loss: 0.60, D_acc: 0.64, G_loss: 0.93
# Epoch: 10601/30000, D_loss: 0.62, D_acc: 0.70, G_loss: 0.91
# Epoch: 10701/30000, D_loss: 0.72, D_acc: 0.58, G_loss: 0.92
# Epoch: 10801/30000, D_loss: 0.57, D_acc: 0.73, G_loss: 1.03
# Epoch: 10901/30000, D_loss: 0.67, D_acc: 0.62, G_loss: 0.98
# Epoch: 11001/30000, D_loss: 0.64, D_acc: 0.61, G_loss: 0.89
# Epoch: 11101/30000, D_loss: 0.61, D_acc: 0.70, G_loss: 1.01
# Epoch: 11201/30000, D_loss: 0.60, D_acc: 0.69, G_loss: 1.05
# Epoch: 11301/30000, D_loss: 0.65, D_acc: 0.59, G_loss: 0.99
# Epoch: 11401/30000, D_loss: 0.60, D_acc: 0.70, G_loss: 0.92
# Epoch: 11501/30000, D_loss: 0.60, D_acc: 0.73, G_loss: 0.99
# Epoch: 11601/30000, D_loss: 0.71, D_acc: 0.52, G_loss: 0.94
# Epoch: 11701/30000, D_loss: 0.69, D_acc: 0.64, G_loss: 0.96
# Epoch: 11801/30000, D_loss: 0.66, D_acc: 0.61, G_loss: 0.97
# Epoch: 11901/30000, D_loss: 0.65, D_acc: 0.67, G_loss: 1.08
# Epoch: 12001/30000, D_loss: 0.72, D_acc: 0.55, G_loss: 0.99
# Epoch: 12101/30000, D_loss: 0.64, D_acc: 0.59, G_loss: 1.05
# Epoch: 12201/30000, D_loss: 0.63, D_acc: 0.69, G_loss: 0.78
# Epoch: 12301/30000, D_loss: 0.57, D_acc: 0.70, G_loss: 0.95
# Epoch: 12401/30000, D_loss: 0.55, D_acc: 0.78, G_loss: 1.06
# Epoch: 12501/30000, D_loss: 0.67, D_acc: 0.62, G_loss: 1.12
# Epoch: 12601/30000, D_loss: 0.53, D_acc: 0.83, G_loss: 1.10
# Epoch: 12701/30000, D_loss: 0.57, D_acc: 0.70, G_loss: 0.93
# Epoch: 12801/30000, D_loss: 0.61, D_acc: 0.75, G_loss: 0.96
# Epoch: 12901/30000, D_loss: 0.68, D_acc: 0.55, G_loss: 0.86
# Epoch: 13001/30000, D_loss: 0.64, D_acc: 0.61, G_loss: 1.01
# Epoch: 13101/30000, D_loss: 0.62, D_acc: 0.61, G_loss: 0.91
# Epoch: 13201/30000, D_loss: 0.63, D_acc: 0.66, G_loss: 0.88
# Epoch: 13301/30000, D_loss: 0.72, D_acc: 0.53, G_loss: 0.93
# Epoch: 13401/30000, D_loss: 0.68, D_acc: 0.66, G_loss: 1.02
# Epoch: 13501/30000, D_loss: 0.72, D_acc: 0.59, G_loss: 1.07
# Epoch: 13601/30000, D_loss: 0.68, D_acc: 0.62, G_loss: 0.96
# Epoch: 13701/30000, D_loss: 0.66, D_acc: 0.61, G_loss: 0.93
# Epoch: 13801/30000, D_loss: 0.57, D_acc: 0.72, G_loss: 0.97
# Epoch: 13901/30000, D_loss: 0.62, D_acc: 0.62, G_loss: 0.99
# Epoch: 14001/30000, D_loss: 0.69, D_acc: 0.61, G_loss: 0.98
# Epoch: 14101/30000, D_loss: 0.65, D_acc: 0.59, G_loss: 0.98
# Epoch: 14201/30000, D_loss: 0.56, D_acc: 0.73, G_loss: 0.96
# Epoch: 14301/30000, D_loss: 0.56, D_acc: 0.72, G_loss: 1.07
# Epoch: 14401/30000, D_loss: 0.65, D_acc: 0.55, G_loss: 1.02
# Epoch: 14501/30000, D_loss: 0.70, D_acc: 0.58, G_loss: 0.92
# Epoch: 14601/30000, D_loss: 0.64, D_acc: 0.66, G_loss: 1.03
# Epoch: 14701/30000, D_loss: 0.68, D_acc: 0.53, G_loss: 1.06
# Epoch: 14801/30000, D_loss: 0.68, D_acc: 0.59, G_loss: 1.05
# Epoch: 14901/30000, D_loss: 0.63, D_acc: 0.64, G_loss: 1.00
# Epoch: 15001/30000, D_loss: 0.69, D_acc: 0.61, G_loss: 1.00
# Epoch: 15101/30000, D_loss: 0.67, D_acc: 0.59, G_loss: 0.87
# Epoch: 15201/30000, D_loss: 0.61, D_acc: 0.69, G_loss: 1.00
# Epoch: 15301/30000, D_loss: 0.72, D_acc: 0.58, G_loss: 0.97
# Epoch: 15401/30000, D_loss: 0.63, D_acc: 0.64, G_loss: 0.98
# Epoch: 15501/30000, D_loss: 0.68, D_acc: 0.64, G_loss: 1.00
# Epoch: 15601/30000, D_loss: 0.70, D_acc: 0.56, G_loss: 0.94
# Epoch: 15701/30000, D_loss: 0.66, D_acc: 0.58, G_loss: 0.86
# Epoch: 15801/30000, D_loss: 0.60, D_acc: 0.70, G_loss: 0.97
# Epoch: 15901/30000, D_loss: 0.62, D_acc: 0.64, G_loss: 0.95
# Epoch: 16001/30000, D_loss: 0.64, D_acc: 0.64, G_loss: 0.97
# Epoch: 16101/30000, D_loss: 0.67, D_acc: 0.64, G_loss: 1.06
# Epoch: 16201/30000, D_loss: 0.66, D_acc: 0.70, G_loss: 1.06
# Epoch: 16301/30000, D_loss: 0.61, D_acc: 0.66, G_loss: 0.99
# Epoch: 16401/30000, D_loss: 0.66, D_acc: 0.59, G_loss: 0.96
# Epoch: 16501/30000, D_loss: 0.66, D_acc: 0.59, G_loss: 1.09
# Epoch: 16601/30000, D_loss: 0.62, D_acc: 0.61, G_loss: 1.01
# Epoch: 16701/30000, D_loss: 0.52, D_acc: 0.84, G_loss: 0.90
# Epoch: 16801/30000, D_loss: 0.67, D_acc: 0.52, G_loss: 0.94
# Epoch: 16901/30000, D_loss: 0.58, D_acc: 0.69, G_loss: 1.07
# Epoch: 17001/30000, D_loss: 0.60, D_acc: 0.72, G_loss: 0.96
# Epoch: 17101/30000, D_loss: 0.62, D_acc: 0.64, G_loss: 0.97
# Epoch: 17201/30000, D_loss: 0.60, D_acc: 0.66, G_loss: 1.00
# Epoch: 17301/30000, D_loss: 0.60, D_acc: 0.69, G_loss: 0.99
# Epoch: 17401/30000, D_loss: 0.65, D_acc: 0.64, G_loss: 0.97
# Epoch: 17501/30000, D_loss: 0.58, D_acc: 0.72, G_loss: 0.84
# Epoch: 17601/30000, D_loss: 0.67, D_acc: 0.66, G_loss: 1.03
# Epoch: 17701/30000, D_loss: 0.64, D_acc: 0.66, G_loss: 0.97
# Epoch: 17801/30000, D_loss: 0.68, D_acc: 0.61, G_loss: 0.92
# Epoch: 17901/30000, D_loss: 0.64, D_acc: 0.62, G_loss: 1.05
# Epoch: 18001/30000, D_loss: 0.56, D_acc: 0.73, G_loss: 0.92
# Epoch: 18101/30000, D_loss: 0.63, D_acc: 0.64, G_loss: 0.95
# Epoch: 18201/30000, D_loss: 0.67, D_acc: 0.66, G_loss: 1.12
# Epoch: 18301/30000, D_loss: 0.75, D_acc: 0.47, G_loss: 0.99
# Epoch: 18401/30000, D_loss: 0.77, D_acc: 0.48, G_loss: 0.89
# Epoch: 18501/30000, D_loss: 0.64, D_acc: 0.62, G_loss: 0.88
# Epoch: 18601/30000, D_loss: 0.69, D_acc: 0.55, G_loss: 1.05
# Epoch: 18701/30000, D_loss: 0.66, D_acc: 0.59, G_loss: 0.99
# Epoch: 18801/30000, D_loss: 0.62, D_acc: 0.67, G_loss: 1.12
# Epoch: 18901/30000, D_loss: 0.56, D_acc: 0.72, G_loss: 1.01
# Epoch: 19001/30000, D_loss: 0.65, D_acc: 0.62, G_loss: 0.98
# Epoch: 19101/30000, D_loss: 0.70, D_acc: 0.53, G_loss: 1.03
# Epoch: 19201/30000, D_loss: 0.65, D_acc: 0.62, G_loss: 0.91
# Epoch: 19301/30000, D_loss: 0.60, D_acc: 0.67, G_loss: 0.95
# Epoch: 19401/30000, D_loss: 0.65, D_acc: 0.59, G_loss: 0.93
# Epoch: 19501/30000, D_loss: 0.60, D_acc: 0.69, G_loss: 0.99
# Epoch: 19601/30000, D_loss: 0.69, D_acc: 0.53, G_loss: 1.01
# Epoch: 19701/30000, D_loss: 0.65, D_acc: 0.59, G_loss: 1.02
# Epoch: 19801/30000, D_loss: 0.66, D_acc: 0.61, G_loss: 1.00
# Epoch: 19901/30000, D_loss: 0.62, D_acc: 0.72, G_loss: 0.96
# Epoch: 20001/30000, D_loss: 0.66, D_acc: 0.59, G_loss: 1.06
# Epoch: 20101/30000, D_loss: 0.67, D_acc: 0.56, G_loss: 0.87
# Epoch: 20201/30000, D_loss: 0.61, D_acc: 0.64, G_loss: 0.99
# Epoch: 20301/30000, D_loss: 0.61, D_acc: 0.64, G_loss: 0.98
# Epoch: 20401/30000, D_loss: 0.70, D_acc: 0.62, G_loss: 0.95
# Epoch: 20501/30000, D_loss: 0.62, D_acc: 0.64, G_loss: 0.94
# Epoch: 20601/30000, D_loss: 0.66, D_acc: 0.61, G_loss: 1.00
# Epoch: 20701/30000, D_loss: 0.64, D_acc: 0.61, G_loss: 1.12
# Epoch: 20801/30000, D_loss: 0.60, D_acc: 0.72, G_loss: 1.08
# Epoch: 20901/30000, D_loss: 0.60, D_acc: 0.72, G_loss: 0.93
# Epoch: 21001/30000, D_loss: 0.67, D_acc: 0.62, G_loss: 0.95
# Epoch: 21101/30000, D_loss: 0.71, D_acc: 0.52, G_loss: 0.94
# Epoch: 21201/30000, D_loss: 0.59, D_acc: 0.69, G_loss: 1.00
# Epoch: 21301/30000, D_loss: 0.67, D_acc: 0.56, G_loss: 1.03
# Epoch: 21401/30000, D_loss: 0.65, D_acc: 0.72, G_loss: 0.94
# Epoch: 21501/30000, D_loss: 0.56, D_acc: 0.80, G_loss: 1.01
# Epoch: 21601/30000, D_loss: 0.61, D_acc: 0.67, G_loss: 1.04
# Epoch: 21701/30000, D_loss: 0.68, D_acc: 0.55, G_loss: 1.01
# Epoch: 21801/30000, D_loss: 0.66, D_acc: 0.61, G_loss: 0.99
# Epoch: 21901/30000, D_loss: 0.58, D_acc: 0.73, G_loss: 0.81
# Epoch: 22001/30000, D_loss: 0.61, D_acc: 0.69, G_loss: 1.06
# Epoch: 22101/30000, D_loss: 0.65, D_acc: 0.59, G_loss: 0.91
# Epoch: 22201/30000, D_loss: 0.67, D_acc: 0.55, G_loss: 1.03
# Epoch: 22301/30000, D_loss: 0.70, D_acc: 0.62, G_loss: 0.98
# Epoch: 22401/30000, D_loss: 0.58, D_acc: 0.67, G_loss: 1.05
# Epoch: 22501/30000, D_loss: 0.67, D_acc: 0.61, G_loss: 1.10
# Epoch: 22601/30000, D_loss: 0.63, D_acc: 0.66, G_loss: 1.01
# Epoch: 22701/30000, D_loss: 0.64, D_acc: 0.67, G_loss: 0.92
# Epoch: 22801/30000, D_loss: 0.55, D_acc: 0.73, G_loss: 0.99
# Epoch: 22901/30000, D_loss: 0.71, D_acc: 0.48, G_loss: 0.94
# Epoch: 23001/30000, D_loss: 0.65, D_acc: 0.59, G_loss: 1.07
# Epoch: 23101/30000, D_loss: 0.75, D_acc: 0.55, G_loss: 1.02
# Epoch: 23201/30000, D_loss: 0.64, D_acc: 0.66, G_loss: 1.04
# Epoch: 23301/30000, D_loss: 0.65, D_acc: 0.62, G_loss: 0.93
# Epoch: 23401/30000, D_loss: 0.60, D_acc: 0.66, G_loss: 0.95
# Epoch: 23501/30000, D_loss: 0.63, D_acc: 0.67, G_loss: 1.08
# Epoch: 23601/30000, D_loss: 0.68, D_acc: 0.58, G_loss: 1.12
# Epoch: 23701/30000, D_loss: 0.59, D_acc: 0.73, G_loss: 0.87
# Epoch: 23801/30000, D_loss: 0.60, D_acc: 0.67, G_loss: 1.02
# Epoch: 23901/30000, D_loss: 0.63, D_acc: 0.66, G_loss: 0.91
# Epoch: 24001/30000, D_loss: 0.63, D_acc: 0.62, G_loss: 0.89
# Epoch: 24101/30000, D_loss: 0.66, D_acc: 0.56, G_loss: 1.19
# Epoch: 24201/30000, D_loss: 0.60, D_acc: 0.66, G_loss: 0.96
# Epoch: 24301/30000, D_loss: 0.63, D_acc: 0.59, G_loss: 1.07
# Epoch: 24401/30000, D_loss: 0.68, D_acc: 0.61, G_loss: 0.99
# Epoch: 24501/30000, D_loss: 0.67, D_acc: 0.61, G_loss: 1.13
# Epoch: 24601/30000, D_loss: 0.66, D_acc: 0.55, G_loss: 0.91
# Epoch: 24701/30000, D_loss: 0.59, D_acc: 0.67, G_loss: 0.92
# Epoch: 24801/30000, D_loss: 0.61, D_acc: 0.66, G_loss: 1.10
# Epoch: 24901/30000, D_loss: 0.57, D_acc: 0.72, G_loss: 1.02
# Epoch: 25001/30000, D_loss: 0.64, D_acc: 0.64, G_loss: 1.11
# Epoch: 25101/30000, D_loss: 0.72, D_acc: 0.61, G_loss: 1.12
# Epoch: 25201/30000, D_loss: 0.67, D_acc: 0.62, G_loss: 1.04
# Epoch: 25301/30000, D_loss: 0.59, D_acc: 0.62, G_loss: 1.11
# Epoch: 25401/30000, D_loss: 0.62, D_acc: 0.66, G_loss: 1.02
# Epoch: 25501/30000, D_loss: 0.71, D_acc: 0.53, G_loss: 1.06
# Epoch: 25601/30000, D_loss: 0.53, D_acc: 0.77, G_loss: 0.94
# Epoch: 25701/30000, D_loss: 0.63, D_acc: 0.69, G_loss: 0.93
# Epoch: 25801/30000, D_loss: 0.68, D_acc: 0.56, G_loss: 0.92
# Epoch: 25901/30000, D_loss: 0.68, D_acc: 0.55, G_loss: 1.07
# Epoch: 26001/30000, D_loss: 0.64, D_acc: 0.70, G_loss: 0.98
# Epoch: 26101/30000, D_loss: 0.55, D_acc: 0.78, G_loss: 1.08
# Epoch: 26201/30000, D_loss: 0.68, D_acc: 0.59, G_loss: 0.87
# Epoch: 26301/30000, D_loss: 0.60, D_acc: 0.66, G_loss: 1.02
# Epoch: 26401/30000, D_loss: 0.64, D_acc: 0.59, G_loss: 0.97
# Epoch: 26501/30000, D_loss: 0.62, D_acc: 0.67, G_loss: 0.96
# Epoch: 26601/30000, D_loss: 0.69, D_acc: 0.56, G_loss: 0.98
# Epoch: 26701/30000, D_loss: 0.64, D_acc: 0.62, G_loss: 1.02
# Epoch: 26801/30000, D_loss: 0.59, D_acc: 0.67, G_loss: 1.15
# Epoch: 26901/30000, D_loss: 0.69, D_acc: 0.53, G_loss: 0.96
# Epoch: 27001/30000, D_loss: 0.63, D_acc: 0.62, G_loss: 1.07
# Epoch: 27101/30000, D_loss: 0.61, D_acc: 0.69, G_loss: 1.02
# Epoch: 27201/30000, D_loss: 0.56, D_acc: 0.72, G_loss: 1.20
# Epoch: 27301/30000, D_loss: 0.60, D_acc: 0.69, G_loss: 1.08
# Epoch: 27401/30000, D_loss: 0.55, D_acc: 0.78, G_loss: 1.05
# Epoch: 27501/30000, D_loss: 0.56, D_acc: 0.70, G_loss: 0.99
# Epoch: 27601/30000, D_loss: 0.66, D_acc: 0.56, G_loss: 1.02
# Epoch: 27701/30000, D_loss: 0.56, D_acc: 0.72, G_loss: 1.13
# Epoch: 27801/30000, D_loss: 0.56, D_acc: 0.72, G_loss: 1.01
# Epoch: 27901/30000, D_loss: 0.69, D_acc: 0.56, G_loss: 1.04
# Epoch: 28001/30000, D_loss: 0.60, D_acc: 0.70, G_loss: 1.02
# Epoch: 28101/30000, D_loss: 0.61, D_acc: 0.67, G_loss: 1.15
# Epoch: 28201/30000, D_loss: 0.70, D_acc: 0.58, G_loss: 0.86
# Epoch: 28301/30000, D_loss: 0.64, D_acc: 0.61, G_loss: 1.06
# Epoch: 28401/30000, D_loss: 0.58, D_acc: 0.69, G_loss: 1.07
# Epoch: 28501/30000, D_loss: 0.58, D_acc: 0.67, G_loss: 1.07
# Epoch: 28601/30000, D_loss: 0.56, D_acc: 0.73, G_loss: 1.03
# Epoch: 28701/30000, D_loss: 0.61, D_acc: 0.72, G_loss: 0.97
# Epoch: 28801/30000, D_loss: 0.71, D_acc: 0.55, G_loss: 1.02
# Epoch: 28901/30000, D_loss: 0.68, D_acc: 0.67, G_loss: 1.02
# Epoch: 29001/30000, D_loss: 0.66, D_acc: 0.58, G_loss: 1.05
# Epoch: 29101/30000, D_loss: 0.64, D_acc: 0.61, G_loss: 1.04
# Epoch: 29201/30000, D_loss: 0.57, D_acc: 0.66, G_loss: 1.13
# Epoch: 29301/30000, D_loss: 0.64, D_acc: 0.61, G_loss: 1.06
# Epoch: 29401/30000, D_loss: 0.64, D_acc: 0.62, G_loss: 1.11
# Epoch: 29501/30000, D_loss: 0.55, D_acc: 0.70, G_loss: 1.08
# Epoch: 29601/30000, D_loss: 0.62, D_acc: 0.61, G_loss: 0.95
# Epoch: 29701/30000, D_loss: 0.62, D_acc: 0.58, G_loss: 1.00
# Epoch: 29801/30000, D_loss: 0.68, D_acc: 0.62, G_loss: 0.90
# Epoch: 29901/30000, D_loss: 0.59, D_acc: 0.72, G_loss: 0.97

# %%
plt.plot(d_losses, label="Discriminator Loss")
plt.plot(g_losses, label="Generator Loss")
plt.show()
