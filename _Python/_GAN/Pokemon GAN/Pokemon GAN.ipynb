# %%
# Imports
import tensorflow
from tensorflow.keras.models import Model 
from tensorflow.keras.layers import Input, Dense, Flatten, Reshape, MaxPool2D, Conv2D, UpSampling2D, Conv2DTranspose, LeakyReLU
from tensorflow.keras.optimizers import Adam

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load data
x_train = np.load("/content/drive/MyDrive/Colab Notebooks/Datasets/Pokemon_Data.npy")

plt.imshow(x_train[715])
plt.show()

# %%
# Dataset settings
D = x_train.shape[0]
W = x_train.shape[1]
H = x_train.shape[2]
d = x_train.shape[3]

latent_dim = 256

print(x_train.shape)
# Out:
# (891, 40, 40, 3)

# %%
# Create the model
def create_generator(latent_dim):
    i = Input(shape=(latent_dim,))
    x = Dense(1024, activation=LeakyReLU(alpha=0.2))(i)
    x = Reshape(target_shape=(4, 4, 64))(x)
    x = Conv2D(32, (2, 2), activation=LeakyReLU(alpha=0.2))(x)
    x = UpSampling2D()(x)
    x = Conv2D(16, (2, 2), activation=LeakyReLU(alpha=0.2))(x)
    x = UpSampling2D()(x)
    x = Flatten()(x)
    x = Dense(2400, activation=LeakyReLU(alpha=0.2))(x)
    x = Dense(4800, activation=LeakyReLU(alpha=0.2))(x)
    x = Dense(4800, activation="sigmoid")(x)
    x = Reshape(target_shape=(40, 40, 3))(x)

    model = Model(i, x)
    return model

# %%
def create_discriminator(image_shape):
    i = Input(shape=(image_shape))
    x = Conv2D(8, (2, 2), activation=LeakyReLU(alpha=0.2))(i)
    x = MaxPool2D()(x)
    x = Conv2D(16, (2, 2), activation=LeakyReLU(alpha=0.2))(x)
    x = MaxPool2D()(x)
    x = Conv2D(32, (2, 2), activation=LeakyReLU(alpha=0.2))(x)
    x = MaxPool2D()(x)
    x = Flatten()(x)
    x = Dense(128, activation=LeakyReLU(alpha=0.2))(x)
    x = Dense(1, activation="sigmoid")(x)

    model = Model(i, x)
    return model

# %%
# Compile the models
generator = create_generator(latent_dim)
discriminator = create_discriminator(x_train[0].shape)

discriminator.compile(
    loss="binary_crossentropy",
    optimizer=Adam(0.0002, 0.5),
    metrics=["accuracy"]
)

z = Input(shape=(latent_dim,))
img = generator(z)
discriminator.trainable = False

fake_pred = discriminator(img)

gan = Model(z, fake_pred)
gan.compile(
    loss="binary_crossentropy",
    optimizer=Adam(0.0002, 0.5)
)

# print(generator.summary())
# print(discriminator.summary())
# print(gan.summary())

# %%
# Config for training the models
batch_size = 32
epochs = 30000
sample_period = 200

ones = np.ones(batch_size)
zeros = np.zeros(batch_size)

d_losses = []
g_losses = []

image_path = "/content/drive/My Drive/Colab Notebooks/Outputs/Pokemon Gan"

if not os.path.exists(image_path):
    os.mkdir(image_path)

# %%
def sample_images(epoch):
    rows, cols = 5, 5
    noise = np.random.randn(rows * cols, latent_dim)
    imgs = generator.predict(noise)

    imgs = 0.5 * imgs + 0.5

    fig, axs = plt.subplots(rows, cols)
    idx = 0
    for i in range(rows):
        for j in range(cols):
            axs[i, j].imshow(imgs[idx].reshape(H, W, d), cmap="gray")
            axs[i, j].axis("off")
            idx += 1
    fig.savefig(image_path + "/%d.png" % epoch)
    plt.close()

# %%
# Main train loop
for epoch in range(epochs):
    # Select a random batch of images
    idx = np.random.randint(0, x_train.shape[0], batch_size)
    real_imgs = x_train[idx]

    # Generate fake images
    noise = np.random.randn(batch_size, latent_dim)
    fake_imgs = generator.predict(noise)

    # Train discriminator
    d_loss, d_acc = discriminator.train_on_batch(np.concatenate(real_imgs, fake_imgs), np.concatenate(ones, zeros)

    # Train generator
    noise = np.random.randn(batch_size, latent_dim)
    g_loss = gan.train_on_batch(noise, ones)


    # Save losses
    d_losses.append(d_loss)
    g_losses.append(g_loss)

    if (epoch % 100 == 0):
        print(f"Epoch: {epoch + 1}/{epochs}, D_loss: {d_loss:.2f}, D_acc: {d_acc:.2f}, G_loss: {g_loss:.2f}")
    
    if (epoch % sample_period == 0):
        sample_images(epoch)
# Out:
# Epoch: 1/30000, D_loss: 0.72, D_acc: 0.31, G_loss: 0.64
# Epoch: 101/30000, D_loss: 0.74, D_acc: 0.33, G_loss: 0.63
# Epoch: 201/30000, D_loss: 0.72, D_acc: 0.38, G_loss: 0.65
# Epoch: 301/30000, D_loss: 0.71, D_acc: 0.34, G_loss: 0.67
# Epoch: 401/30000, D_loss: 0.71, D_acc: 0.30, G_loss: 0.67
# Epoch: 501/30000, D_loss: 0.71, D_acc: 0.19, G_loss: 0.68
# Epoch: 601/30000, D_loss: 0.70, D_acc: 0.27, G_loss: 0.69
# Epoch: 701/30000, D_loss: 0.70, D_acc: 0.23, G_loss: 0.69
# Epoch: 801/30000, D_loss: 0.70, D_acc: 0.06, G_loss: 0.69
# Epoch: 901/30000, D_loss: 0.70, D_acc: 0.28, G_loss: 0.69
# Epoch: 1001/30000, D_loss: 0.70, D_acc: 0.22, G_loss: 0.69
# Epoch: 1101/30000, D_loss: 0.70, D_acc: 0.02, G_loss: 0.69
# Epoch: 1201/30000, D_loss: 0.70, D_acc: 0.45, G_loss: 0.70
# Epoch: 1301/30000, D_loss: 0.70, D_acc: 0.00, G_loss: 0.70
# Epoch: 1401/30000, D_loss: 0.70, D_acc: 0.06, G_loss: 0.69
# Epoch: 1501/30000, D_loss: 0.70, D_acc: 0.23, G_loss: 0.69
# Epoch: 1601/30000, D_loss: 0.70, D_acc: 0.27, G_loss: 0.69
# Epoch: 1701/30000, D_loss: 0.69, D_acc: 0.48, G_loss: 0.69
# Epoch: 1801/30000, D_loss: 0.70, D_acc: 0.09, G_loss: 0.70
# Epoch: 1901/30000, D_loss: 0.70, D_acc: 0.45, G_loss: 0.68
# Epoch: 2001/30000, D_loss: 0.70, D_acc: 0.50, G_loss: 0.69
# Epoch: 2101/30000, D_loss: 0.70, D_acc: 0.33, G_loss: 0.69
# Epoch: 2201/30000, D_loss: 0.69, D_acc: 0.50, G_loss: 0.69
# Epoch: 2301/30000, D_loss: 0.69, D_acc: 0.41, G_loss: 0.69
# Epoch: 2401/30000, D_loss: 0.69, D_acc: 0.38, G_loss: 0.69
# Epoch: 2501/30000, D_loss: 0.70, D_acc: 0.41, G_loss: 0.69
# Epoch: 2601/30000, D_loss: 0.70, D_acc: 0.00, G_loss: 0.70
# Epoch: 2701/30000, D_loss: 0.69, D_acc: 0.50, G_loss: 0.70
# Epoch: 2801/30000, D_loss: 0.70, D_acc: 0.27, G_loss: 0.69
# Epoch: 2901/30000, D_loss: 0.69, D_acc: 0.61, G_loss: 0.70
# Epoch: 3001/30000, D_loss: 0.69, D_acc: 0.31, G_loss: 0.69
# Epoch: 3101/30000, D_loss: 0.70, D_acc: 0.03, G_loss: 0.69
# Epoch: 3201/30000, D_loss: 0.70, D_acc: 0.30, G_loss: 0.69
# Epoch: 3301/30000, D_loss: 0.70, D_acc: 0.02, G_loss: 0.69
# Epoch: 3401/30000, D_loss: 0.69, D_acc: 0.22, G_loss: 0.70
# Epoch: 3501/30000, D_loss: 0.70, D_acc: 0.53, G_loss: 0.70
# Epoch: 3601/30000, D_loss: 0.70, D_acc: 0.31, G_loss: 0.69
# Epoch: 3701/30000, D_loss: 0.70, D_acc: 0.53, G_loss: 0.70
# Epoch: 3801/30000, D_loss: 0.70, D_acc: 0.06, G_loss: 0.69
# Epoch: 3901/30000, D_loss: 0.70, D_acc: 0.28, G_loss: 0.69
# Epoch: 4001/30000, D_loss: 0.69, D_acc: 0.44, G_loss: 0.68
# Epoch: 4101/30000, D_loss: 0.69, D_acc: 0.52, G_loss: 0.71
# Epoch: 4201/30000, D_loss: 0.69, D_acc: 0.59, G_loss: 0.70
# Epoch: 4301/30000, D_loss: 0.70, D_acc: 0.19, G_loss: 0.69
# Epoch: 4401/30000, D_loss: 0.70, D_acc: 0.47, G_loss: 0.67
# Epoch: 4501/30000, D_loss: 0.69, D_acc: 0.55, G_loss: 0.70
# Epoch: 4601/30000, D_loss: 0.69, D_acc: 0.50, G_loss: 0.69
# Epoch: 4701/30000, D_loss: 0.69, D_acc: 0.34, G_loss: 0.69
# Epoch: 4801/30000, D_loss: 0.71, D_acc: 0.27, G_loss: 0.66
# Epoch: 4901/30000, D_loss: 0.69, D_acc: 0.56, G_loss: 0.72
# Epoch: 5001/30000, D_loss: 0.69, D_acc: 0.52, G_loss: 0.72
# Epoch: 5101/30000, D_loss: 0.70, D_acc: 0.02, G_loss: 0.70
# Epoch: 5201/30000, D_loss: 0.69, D_acc: 0.64, G_loss: 0.71
# Epoch: 5301/30000, D_loss: 0.68, D_acc: 0.83, G_loss: 0.70
# Epoch: 5401/30000, D_loss: 0.69, D_acc: 0.42, G_loss: 0.68
# Epoch: 5501/30000, D_loss: 0.69, D_acc: 0.58, G_loss: 0.72
# Epoch: 5601/30000, D_loss: 0.69, D_acc: 0.84, G_loss: 0.70
# Epoch: 5701/30000, D_loss: 0.72, D_acc: 0.22, G_loss: 0.67
# Epoch: 5801/30000, D_loss: 0.69, D_acc: 0.67, G_loss: 0.71
# Epoch: 5901/30000, D_loss: 0.70, D_acc: 0.44, G_loss: 0.67
# Epoch: 6001/30000, D_loss: 0.69, D_acc: 0.73, G_loss: 0.70
# Epoch: 6101/30000, D_loss: 0.71, D_acc: 0.50, G_loss: 0.73
# Epoch: 6201/30000, D_loss: 0.69, D_acc: 0.31, G_loss: 0.70
# Epoch: 6301/30000, D_loss: 0.69, D_acc: 0.77, G_loss: 0.71
# Epoch: 6401/30000, D_loss: 0.68, D_acc: 0.86, G_loss: 0.72
# Epoch: 6501/30000, D_loss: 0.71, D_acc: 0.03, G_loss: 0.71
# Epoch: 6601/30000, D_loss: 0.70, D_acc: 0.50, G_loss: 0.75
# Epoch: 6701/30000, D_loss: 0.69, D_acc: 0.69, G_loss: 0.71
# Epoch: 6801/30000, D_loss: 0.69, D_acc: 0.52, G_loss: 0.74
# Epoch: 6901/30000, D_loss: 0.68, D_acc: 0.42, G_loss: 0.69
# Epoch: 7001/30000, D_loss: 0.70, D_acc: 0.44, G_loss: 0.61
# Epoch: 7101/30000, D_loss: 0.71, D_acc: 0.22, G_loss: 0.68
# Epoch: 7201/30000, D_loss: 0.68, D_acc: 0.56, G_loss: 0.77
# Epoch: 7301/30000, D_loss: 0.68, D_acc: 0.73, G_loss: 0.72
# Epoch: 7401/30000, D_loss: 0.71, D_acc: 0.17, G_loss: 0.69
# Epoch: 7501/30000, D_loss: 0.71, D_acc: 0.19, G_loss: 0.68
# Epoch: 7601/30000, D_loss: 0.68, D_acc: 0.81, G_loss: 0.73
# Epoch: 7701/30000, D_loss: 0.70, D_acc: 0.17, G_loss: 0.69
# Epoch: 7801/30000, D_loss: 0.65, D_acc: 0.89, G_loss: 0.72
# Epoch: 7901/30000, D_loss: 0.72, D_acc: 0.42, G_loss: 0.59
# Epoch: 8001/30000, D_loss: 0.70, D_acc: 0.50, G_loss: 0.79
# Epoch: 8101/30000, D_loss: 0.68, D_acc: 0.61, G_loss: 0.76
# Epoch: 8201/30000, D_loss: 0.56, D_acc: 0.48, G_loss: 0.69
# Epoch: 8301/30000, D_loss: 0.77, D_acc: 0.09, G_loss: 0.64
# Epoch: 8401/30000, D_loss: 0.68, D_acc: 0.41, G_loss: 0.69
# Epoch: 8501/30000, D_loss: 0.71, D_acc: 0.50, G_loss: 0.73
# Epoch: 8601/30000, D_loss: 0.68, D_acc: 0.42, G_loss: 0.70
# Epoch: 8701/30000, D_loss: 0.72, D_acc: 0.52, G_loss: 0.76
# Epoch: 8801/30000, D_loss: 0.67, D_acc: 0.77, G_loss: 0.73
# Epoch: 8901/30000, D_loss: 0.68, D_acc: 0.50, G_loss: 0.90
# Epoch: 9001/30000, D_loss: 0.69, D_acc: 0.70, G_loss: 0.72
# Epoch: 9101/30000, D_loss: 0.69, D_acc: 0.47, G_loss: 0.59
# Epoch: 9201/30000, D_loss: 0.70, D_acc: 0.53, G_loss: 0.82
# Epoch: 9301/30000, D_loss: 0.69, D_acc: 0.53, G_loss: 0.79
# Epoch: 9401/30000, D_loss: 0.71, D_acc: 0.53, G_loss: 0.80
# Epoch: 9501/30000, D_loss: 0.70, D_acc: 0.27, G_loss: 0.68
# Epoch: 9601/30000, D_loss: 0.67, D_acc: 0.42, G_loss: 0.70
# Epoch: 9701/30000, D_loss: 0.70, D_acc: 0.52, G_loss: 0.71
# Epoch: 9801/30000, D_loss: 0.68, D_acc: 0.50, G_loss: 0.61
# Epoch: 9901/30000, D_loss: 0.59, D_acc: 0.44, G_loss: 0.65
# Epoch: 10001/30000, D_loss: 0.68, D_acc: 0.89, G_loss: 0.71
# Epoch: 10101/30000, D_loss: 0.75, D_acc: 0.27, G_loss: 0.62
# Epoch: 10201/30000, D_loss: 0.64, D_acc: 0.86, G_loss: 0.77
# Epoch: 10301/30000, D_loss: 0.71, D_acc: 0.50, G_loss: 0.71
# Epoch: 10401/30000, D_loss: 0.69, D_acc: 0.61, G_loss: 0.71
# Epoch: 10501/30000, D_loss: 0.70, D_acc: 0.69, G_loss: 0.71
# Epoch: 10601/30000, D_loss: 0.73, D_acc: 0.42, G_loss: 0.65
# Epoch: 10701/30000, D_loss: 0.69, D_acc: 0.42, G_loss: 0.68
# Epoch: 10801/30000, D_loss: 0.70, D_acc: 0.45, G_loss: 0.63
# Epoch: 10901/30000, D_loss: 0.66, D_acc: 0.42, G_loss: 0.69
# Epoch: 11001/30000, D_loss: 0.71, D_acc: 0.61, G_loss: 0.71
# Epoch: 11101/30000, D_loss: 0.72, D_acc: 0.23, G_loss: 0.67
# Epoch: 11201/30000, D_loss: 0.67, D_acc: 0.50, G_loss: 0.92
# Epoch: 11301/30000, D_loss: 0.72, D_acc: 0.14, G_loss: 0.69
# Epoch: 11401/30000, D_loss: 0.73, D_acc: 0.36, G_loss: 0.55
# Epoch: 11501/30000, D_loss: 0.70, D_acc: 0.36, G_loss: 0.69
# Epoch: 11601/30000, D_loss: 0.66, D_acc: 0.39, G_loss: 0.67
# Epoch: 11701/30000, D_loss: 0.66, D_acc: 0.48, G_loss: 0.66
# Epoch: 11801/30000, D_loss: 0.64, D_acc: 0.59, G_loss: 0.90
# Epoch: 11901/30000, D_loss: 0.72, D_acc: 0.53, G_loss: 0.77
# Epoch: 12001/30000, D_loss: 0.69, D_acc: 0.36, G_loss: 0.66
# Epoch: 12101/30000, D_loss: 0.67, D_acc: 0.84, G_loss: 0.73
# Epoch: 12201/30000, D_loss: 0.71, D_acc: 0.39, G_loss: 0.61
# Epoch: 12301/30000, D_loss: 0.70, D_acc: 0.52, G_loss: 0.77
# Epoch: 12401/30000, D_loss: 0.66, D_acc: 0.88, G_loss: 0.71
# Epoch: 12501/30000, D_loss: 0.54, D_acc: 0.86, G_loss: 0.71
# Epoch: 12601/30000, D_loss: 0.70, D_acc: 0.14, G_loss: 0.70
# Epoch: 12701/30000, D_loss: 0.67, D_acc: 0.34, G_loss: 0.71
# Epoch: 12801/30000, D_loss: 0.70, D_acc: 0.50, G_loss: 0.72
# Epoch: 12901/30000, D_loss: 0.69, D_acc: 0.31, G_loss: 0.69
# Epoch: 13001/30000, D_loss: 0.64, D_acc: 0.86, G_loss: 0.79
# Epoch: 13101/30000, D_loss: 0.66, D_acc: 0.50, G_loss: 0.95
# Epoch: 13201/30000, D_loss: 0.70, D_acc: 0.41, G_loss: 0.66
# Epoch: 13301/30000, D_loss: 0.67, D_acc: 0.47, G_loss: 0.66
# Epoch: 13401/30000, D_loss: 0.70, D_acc: 0.47, G_loss: 0.65
# Epoch: 13501/30000, D_loss: 0.69, D_acc: 0.70, G_loss: 0.71
# Epoch: 13601/30000, D_loss: 0.69, D_acc: 0.33, G_loss: 0.70
# Epoch: 13701/30000, D_loss: 0.68, D_acc: 0.77, G_loss: 0.72
# Epoch: 13801/30000, D_loss: 0.70, D_acc: 0.33, G_loss: 0.70
# Epoch: 13901/30000, D_loss: 0.68, D_acc: 0.48, G_loss: 0.67
# Epoch: 14001/30000, D_loss: 0.70, D_acc: 0.58, G_loss: 0.75
# Epoch: 14101/30000, D_loss: 0.66, D_acc: 0.59, G_loss: 0.76
# Epoch: 14201/30000, D_loss: 0.69, D_acc: 0.77, G_loss: 0.72
# Epoch: 14301/30000, D_loss: 0.69, D_acc: 0.72, G_loss: 0.72
# Epoch: 14401/30000, D_loss: 0.70, D_acc: 0.16, G_loss: 0.69
# Epoch: 14501/30000, D_loss: 0.69, D_acc: 0.58, G_loss: 0.78
# Epoch: 14601/30000, D_loss: 0.68, D_acc: 0.73, G_loss: 0.72
# Epoch: 14701/30000, D_loss: 0.67, D_acc: 0.72, G_loss: 0.74
# Epoch: 14801/30000, D_loss: 0.70, D_acc: 0.72, G_loss: 0.71
# Epoch: 14901/30000, D_loss: 0.64, D_acc: 0.56, G_loss: 0.98
# Epoch: 15001/30000, D_loss: 0.69, D_acc: 0.45, G_loss: 0.67
# Epoch: 15101/30000, D_loss: 0.64, D_acc: 0.69, G_loss: 0.95
# Epoch: 15201/30000, D_loss: 0.72, D_acc: 0.55, G_loss: 0.71
# Epoch: 15301/30000, D_loss: 0.69, D_acc: 0.44, G_loss: 0.67
# Epoch: 15401/30000, D_loss: 0.79, D_acc: 0.38, G_loss: 0.54
# Epoch: 15501/30000, D_loss: 0.67, D_acc: 0.80, G_loss: 0.72
# Epoch: 15601/30000, D_loss: 0.65, D_acc: 0.66, G_loss: 0.88
# Epoch: 15701/30000, D_loss: 0.69, D_acc: 0.55, G_loss: 0.75
# Epoch: 15801/30000, D_loss: 0.65, D_acc: 0.77, G_loss: 0.77
# Epoch: 15901/30000, D_loss: 0.68, D_acc: 0.67, G_loss: 0.79
# Epoch: 16001/30000, D_loss: 0.64, D_acc: 0.77, G_loss: 0.87
# Epoch: 16101/30000, D_loss: 0.67, D_acc: 0.55, G_loss: 0.86
# Epoch: 16201/30000, D_loss: 0.64, D_acc: 0.59, G_loss: 0.97
# Epoch: 16301/30000, D_loss: 0.67, D_acc: 0.50, G_loss: 0.68
# Epoch: 16401/30000, D_loss: 0.70, D_acc: 0.45, G_loss: 0.70
# Epoch: 16501/30000, D_loss: 0.71, D_acc: 0.39, G_loss: 0.66
# Epoch: 16601/30000, D_loss: 0.69, D_acc: 0.44, G_loss: 0.71
# Epoch: 16701/30000, D_loss: 0.73, D_acc: 0.41, G_loss: 0.63
# Epoch: 16801/30000, D_loss: 0.70, D_acc: 0.53, G_loss: 0.73
# Epoch: 16901/30000, D_loss: 0.72, D_acc: 0.39, G_loss: 0.64
# Epoch: 17001/30000, D_loss: 0.70, D_acc: 0.36, G_loss: 0.67
# Epoch: 17101/30000, D_loss: 0.64, D_acc: 0.62, G_loss: 0.94
# Epoch: 17201/30000, D_loss: 0.71, D_acc: 0.39, G_loss: 0.65
# Epoch: 17301/30000, D_loss: 0.68, D_acc: 0.73, G_loss: 0.73
# Epoch: 17401/30000, D_loss: 0.75, D_acc: 0.36, G_loss: 0.60
# Epoch: 17501/30000, D_loss: 0.72, D_acc: 0.28, G_loss: 0.69
# Epoch: 17601/30000, D_loss: 0.60, D_acc: 0.91, G_loss: 0.71
# Epoch: 17701/30000, D_loss: 0.69, D_acc: 0.50, G_loss: 0.82
# Epoch: 17801/30000, D_loss: 0.72, D_acc: 0.27, G_loss: 0.66
# Epoch: 17901/30000, D_loss: 0.67, D_acc: 0.72, G_loss: 0.74
# Epoch: 18001/30000, D_loss: 0.72, D_acc: 0.39, G_loss: 0.67
# Epoch: 18101/30000, D_loss: 0.73, D_acc: 0.25, G_loss: 0.65
# Epoch: 18201/30000, D_loss: 0.67, D_acc: 0.39, G_loss: 0.69
# Epoch: 18301/30000, D_loss: 0.67, D_acc: 0.33, G_loss: 0.70
# Epoch: 18401/30000, D_loss: 0.67, D_acc: 0.48, G_loss: 0.67
# Epoch: 18501/30000, D_loss: 0.88, D_acc: 0.19, G_loss: 0.51
# Epoch: 18601/30000, D_loss: 0.70, D_acc: 0.52, G_loss: 1.02
# Epoch: 18701/30000, D_loss: 0.72, D_acc: 0.52, G_loss: 0.73
# Epoch: 18801/30000, D_loss: 0.80, D_acc: 0.52, G_loss: 1.09
# Epoch: 18901/30000, D_loss: 0.67, D_acc: 0.42, G_loss: 0.67
# Epoch: 19001/30000, D_loss: 0.65, D_acc: 0.78, G_loss: 0.78
# Epoch: 19101/30000, D_loss: 0.68, D_acc: 0.33, G_loss: 0.71
# Epoch: 19201/30000, D_loss: 0.80, D_acc: 0.44, G_loss: 0.76
# Epoch: 19301/30000, D_loss: 0.55, D_acc: 0.47, G_loss: 0.66
# Epoch: 19401/30000, D_loss: 0.67, D_acc: 0.83, G_loss: 0.75
# Epoch: 19501/30000, D_loss: 0.65, D_acc: 0.97, G_loss: 0.72
# Epoch: 19601/30000, D_loss: 0.62, D_acc: 0.62, G_loss: 1.01
# Epoch: 19701/30000, D_loss: 0.65, D_acc: 0.55, G_loss: 1.01
# Epoch: 19801/30000, D_loss: 0.68, D_acc: 0.70, G_loss: 0.73
# Epoch: 19901/30000, D_loss: 0.71, D_acc: 0.64, G_loss: 0.94
# Epoch: 20001/30000, D_loss: 0.75, D_acc: 0.23, G_loss: 0.63
# Epoch: 20101/30000, D_loss: 0.55, D_acc: 0.50, G_loss: 0.70
# Epoch: 20201/30000, D_loss: 0.60, D_acc: 0.62, G_loss: 1.25
# Epoch: 20301/30000, D_loss: 0.71, D_acc: 0.55, G_loss: 0.72
# Epoch: 20401/30000, D_loss: 0.65, D_acc: 0.77, G_loss: 0.78
# Epoch: 20501/30000, D_loss: 0.70, D_acc: 0.25, G_loss: 0.67
# Epoch: 20601/30000, D_loss: 0.68, D_acc: 0.42, G_loss: 0.66
# Epoch: 20701/30000, D_loss: 0.69, D_acc: 0.70, G_loss: 0.74
# Epoch: 20801/30000, D_loss: 0.71, D_acc: 0.66, G_loss: 0.87
# Epoch: 20901/30000, D_loss: 0.64, D_acc: 0.53, G_loss: 0.72
# Epoch: 21001/30000, D_loss: 0.60, D_acc: 0.69, G_loss: 1.02
# Epoch: 21101/30000, D_loss: 0.66, D_acc: 0.50, G_loss: 1.18
# Epoch: 21201/30000, D_loss: 0.70, D_acc: 0.41, G_loss: 0.60
# Epoch: 21301/30000, D_loss: 0.61, D_acc: 0.94, G_loss: 0.82
# Epoch: 21401/30000, D_loss: 0.69, D_acc: 0.72, G_loss: 0.73
# Epoch: 21501/30000, D_loss: 0.66, D_acc: 0.47, G_loss: 0.63
# Epoch: 21601/30000, D_loss: 0.57, D_acc: 0.77, G_loss: 1.04
# Epoch: 21701/30000, D_loss: 0.68, D_acc: 0.78, G_loss: 0.74
# Epoch: 21801/30000, D_loss: 0.79, D_acc: 0.31, G_loss: 0.60
# Epoch: 21901/30000, D_loss: 0.66, D_acc: 0.81, G_loss: 0.77
# Epoch: 22001/30000, D_loss: 0.73, D_acc: 0.47, G_loss: 0.69
# Epoch: 22101/30000, D_loss: 0.69, D_acc: 0.53, G_loss: 0.76
# Epoch: 22201/30000, D_loss: 0.67, D_acc: 0.72, G_loss: 0.76
# Epoch: 22301/30000, D_loss: 0.72, D_acc: 0.06, G_loss: 0.70
# Epoch: 22401/30000, D_loss: 0.70, D_acc: 0.36, G_loss: 0.69
# Epoch: 22501/30000, D_loss: 0.74, D_acc: 0.50, G_loss: 1.17
# Epoch: 22601/30000, D_loss: 0.70, D_acc: 0.50, G_loss: 0.54
# Epoch: 22701/30000, D_loss: 0.69, D_acc: 0.56, G_loss: 0.76
# Epoch: 22801/30000, D_loss: 0.66, D_acc: 0.67, G_loss: 0.82
# Epoch: 22901/30000, D_loss: 0.65, D_acc: 0.50, G_loss: 0.58
# Epoch: 23001/30000, D_loss: 0.64, D_acc: 0.55, G_loss: 1.08
# Epoch: 23101/30000, D_loss: 0.67, D_acc: 0.83, G_loss: 0.73
# Epoch: 23201/30000, D_loss: 0.67, D_acc: 0.59, G_loss: 0.82
# Epoch: 23301/30000, D_loss: 0.65, D_acc: 0.78, G_loss: 0.77
# Epoch: 23401/30000, D_loss: 0.66, D_acc: 0.47, G_loss: 0.71
# Epoch: 23501/30000, D_loss: 0.71, D_acc: 0.58, G_loss: 0.76
# Epoch: 23601/30000, D_loss: 0.67, D_acc: 0.39, G_loss: 0.71
# Epoch: 23701/30000, D_loss: 0.69, D_acc: 0.58, G_loss: 0.71
# Epoch: 23801/30000, D_loss: 0.53, D_acc: 0.50, G_loss: 0.65
# Epoch: 23901/30000, D_loss: 0.69, D_acc: 0.53, G_loss: 0.80
# Epoch: 24001/30000, D_loss: 0.64, D_acc: 0.84, G_loss: 0.76
# Epoch: 24101/30000, D_loss: 0.70, D_acc: 0.36, G_loss: 0.75
# Epoch: 24201/30000, D_loss: 0.68, D_acc: 0.53, G_loss: 0.87
# Epoch: 24301/30000, D_loss: 0.78, D_acc: 0.20, G_loss: 0.61
# Epoch: 24401/30000, D_loss: 0.72, D_acc: 0.44, G_loss: 0.61
# Epoch: 24501/30000, D_loss: 0.68, D_acc: 0.66, G_loss: 0.81
# Epoch: 24601/30000, D_loss: 0.72, D_acc: 0.30, G_loss: 0.73
# Epoch: 24701/30000, D_loss: 0.73, D_acc: 0.31, G_loss: 0.64
# Epoch: 24801/30000, D_loss: 0.72, D_acc: 0.25, G_loss: 0.66
# Epoch: 24901/30000, D_loss: 0.71, D_acc: 0.56, G_loss: 0.72
# Epoch: 25001/30000, D_loss: 0.73, D_acc: 0.27, G_loss: 0.65
# Epoch: 25101/30000, D_loss: 0.70, D_acc: 0.34, G_loss: 0.71
# Epoch: 25201/30000, D_loss: 0.70, D_acc: 0.30, G_loss: 0.72
# Epoch: 25301/30000, D_loss: 0.68, D_acc: 0.70, G_loss: 0.73
# Epoch: 25401/30000, D_loss: 0.64, D_acc: 0.56, G_loss: 0.71
# Epoch: 25501/30000, D_loss: 0.70, D_acc: 0.75, G_loss: 0.74
# Epoch: 25601/30000, D_loss: 0.74, D_acc: 0.55, G_loss: 0.66
# Epoch: 25701/30000, D_loss: 0.62, D_acc: 0.83, G_loss: 0.77
# Epoch: 25801/30000, D_loss: 0.68, D_acc: 0.44, G_loss: 0.72
# Epoch: 25901/30000, D_loss: 0.74, D_acc: 0.19, G_loss: 0.71
# Epoch: 26001/30000, D_loss: 0.69, D_acc: 0.34, G_loss: 0.67
# Epoch: 26101/30000, D_loss: 0.69, D_acc: 0.52, G_loss: 0.82
# Epoch: 26201/30000, D_loss: 0.69, D_acc: 0.42, G_loss: 0.68
# Epoch: 26301/30000, D_loss: 0.66, D_acc: 0.72, G_loss: 0.74
# Epoch: 26401/30000, D_loss: 0.71, D_acc: 0.47, G_loss: 0.62
# Epoch: 26501/30000, D_loss: 0.70, D_acc: 0.36, G_loss: 0.64
# Epoch: 26601/30000, D_loss: 0.65, D_acc: 0.69, G_loss: 0.78
# Epoch: 26701/30000, D_loss: 0.68, D_acc: 0.64, G_loss: 0.91
# Epoch: 26801/30000, D_loss: 0.73, D_acc: 0.30, G_loss: 0.71
# Epoch: 26901/30000, D_loss: 0.69, D_acc: 0.56, G_loss: 0.79
# Epoch: 27001/30000, D_loss: 0.74, D_acc: 0.16, G_loss: 0.70
# Epoch: 27101/30000, D_loss: 0.70, D_acc: 0.56, G_loss: 0.68
# Epoch: 27201/30000, D_loss: 0.71, D_acc: 0.55, G_loss: 0.71
# Epoch: 27301/30000, D_loss: 0.72, D_acc: 0.39, G_loss: 0.68
# Epoch: 27401/30000, D_loss: 0.68, D_acc: 0.81, G_loss: 0.73
# Epoch: 27501/30000, D_loss: 0.69, D_acc: 0.67, G_loss: 0.79
# Epoch: 27601/30000, D_loss: 0.66, D_acc: 0.73, G_loss: 0.74
# Epoch: 27701/30000, D_loss: 0.71, D_acc: 0.58, G_loss: 0.79
# Epoch: 27801/30000, D_loss: 0.74, D_acc: 0.27, G_loss: 0.63
# Epoch: 27901/30000, D_loss: 0.70, D_acc: 0.27, G_loss: 0.70
# Epoch: 28001/30000, D_loss: 0.70, D_acc: 0.62, G_loss: 0.73
# Epoch: 28101/30000, D_loss: 0.72, D_acc: 0.31, G_loss: 0.64
# Epoch: 28201/30000, D_loss: 0.71, D_acc: 0.28, G_loss: 0.68
# Epoch: 28301/30000, D_loss: 0.67, D_acc: 0.67, G_loss: 0.81
# Epoch: 28401/30000, D_loss: 0.68, D_acc: 0.59, G_loss: 0.79
# Epoch: 28501/30000, D_loss: 0.69, D_acc: 0.70, G_loss: 0.67
# Epoch: 28601/30000, D_loss: 0.67, D_acc: 0.59, G_loss: 0.74
# Epoch: 28701/30000, D_loss: 0.66, D_acc: 0.66, G_loss: 0.76
# Epoch: 28801/30000, D_loss: 0.71, D_acc: 0.39, G_loss: 0.67
# Epoch: 28901/30000, D_loss: 0.72, D_acc: 0.53, G_loss: 0.75
# Epoch: 29001/30000, D_loss: 0.73, D_acc: 0.30, G_loss: 0.63
# Epoch: 29101/30000, D_loss: 0.67, D_acc: 0.69, G_loss: 0.80
# Epoch: 29201/30000, D_loss: 0.70, D_acc: 0.39, G_loss: 0.66
# Epoch: 29301/30000, D_loss: 0.73, D_acc: 0.42, G_loss: 0.62
# Epoch: 29401/30000, D_loss: 0.74, D_acc: 0.33, G_loss: 0.66
# Epoch: 29501/30000, D_loss: 0.68, D_acc: 0.66, G_loss: 0.72
# Epoch: 29601/30000, D_loss: 0.70, D_acc: 0.44, G_loss: 0.72
# Epoch: 29701/30000, D_loss: 0.69, D_acc: 0.53, G_loss: 0.83
# Epoch: 29801/30000, D_loss: 0.69, D_acc: 0.64, G_loss: 0.72
# Epoch: 29901/30000, D_loss: 0.72, D_acc: 0.33, G_loss: 0.70

# %%
plt.plot(d_losses, label="Discriminator Loss")
plt.plot(g_losses, label="Generator Loss")
plt.legend()
plt.show()
