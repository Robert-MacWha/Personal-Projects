# %%
import ipywidgets as widgets

# %%
w = widgets.IntSlider()

display(w)
# Out:
# IntSlider(value=0)

# %%
w.value * 42
# Out:
# 2940

# %%
def testFN(test_var):
    print(test_var)

# %%
widgets.interact(testFN, 
                 test_var = (-1, 1, 0.1))
# Out:
# interactive(children=(FloatSlider(value=0.0, description='test_var', max=1.0, min=-1.0), Output()), _dom_class…
# <function __main__.testFN>

# %%
def testFN2(test_var1, test_var2):
    print(test_var1, test_var2)

# %%
widgets.interact(testFN2, 
                 test_var1 = (-1, 1, 0.1),
                 test_var2 = (-1, 1, 0.1))
# Out:
# interactive(children=(FloatSlider(value=0.0, description='test_var1', max=1.0, min=-1.0), FloatSlider(value=0.…
# <function __main__.testFN2>
